# %%
import seaborn as sns
df = sns.load_dataset('titanic')

#sns.countplot(data=df, x='class')
#sns.countplot(data=df, x='class',hue='who')
#sns.countplot(data=df, y='class', hue='alive')

# %%
import pydataset as pds
import seaborn as sns

mtc = pds.data('mtcars')
#print(mtc)
sns.countplot(data=mtc, x='cyl',hue='gear')
# Out:
# <Axes: xlabel='cyl', ylabel='count'>

# %%
students = [80,60,70,50,90]
print("students score is ", sum(students)) #q2
s = sum(students)
print("students's average is ", s/5)
# Out:
# students score is  350
# students's average is  70.0
